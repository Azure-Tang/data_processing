# %%
from retrival import retrivalModel
from pathlib import Path
import os
proxy = 'http://127.0.0.1:20171'
os.environ['http_proxy'] = proxy
os.environ['HTTP_PROXY'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTPS_PROXY'] = proxy
os.environ['all_proxy'] = proxy

# %%
data_input_dir = Path('./raw_datas/3body') # 三体书
data_output_dir = Path('./bgem3_output') # 映射表存放位置
tokenizer_dir = Path('../internlm2-7B') 
tokenized_book_prompt_dir = Path('./output_datas/tokenized_3body_without_prompt') # 三体书分词后的存放位置
tokenized_book_prompt_file = tokenized_book_prompt_dir / 'tokenized_3body.txt'
chunk_size = 250
chunk_overlap = 50
model = retrivalModel(model_name='../bgem3', book_dir='./raw_datas/3body', middle_files_dir=Path("./output_datas/tokenized_prompt"))
# model_0 = retrival_model_0(model_name='../bgem3')
# Out:
# ----------using 8*GPUs----------
# Read ./bgem3_output/3body.pkl complete.

# %%
queries = ['叶文杰拿着什么工具去除巨大树身上枝丫？', # 
           '白沐霖是哪个报社的记者？',
           '马钢伐倒的落叶松有多少岁？',
           '白沐霖从包中掏出一本蓝色封面的书给了叶文杰，是什么书？', #
           '白沐霖在《大生产报》一直工作到哪一年？',
           '被“科学边界”的一些人戏称为“女海明威”的人是谁？',
           '墨子对汪淼说，在汪淼离开的三十六万两千年里，文明又被重新启动了几次？', # 
           '叶文洁和杨卫宁的感情如何？',
           '周文王突然看到一个人骑着马从天边飞奔而来，这个人是谁？', # 1
           '科兹莫博士发现的那颗带有行星的恒星275E1，距太阳系有多远？',
           '187J3X1恒星什么时间被摧毁的？',
           '程心与智子见面后的第二天，来找他的六个公元人的年龄范围？',
           '情报解读委员会（IDC）的第一次会议是在哪里召开的？',
           '查尔斯·米什内尔是谁？'
           ]

# %%
q = queries[4:]
# q = [q]
# 设置全局torch 随机种子
weights_for_different_modes = [1,1,0]
ans = model.retrive_data(queries=q, expand_length=0, top_k=20,weights_for_different_modes=weights_for_different_modes,is_merge_overlaped=True)
# ans0 = model_0.retrive_data(queries=q)
print(q)
# Out:
# ['白沐霖在《大生产报》一直工作到哪一年？', '被“科学边界”的一些人戏称为“女海明威”的人是谁？', '墨子对汪淼说，在汪淼离开的三十六万两千年里，文明又被重新启动了几次？', '叶文洁和杨卫宁的感情如何？', '周文王突然看到一个人骑着马从天边飞奔而来，这个人是谁？', '科兹莫博士发现的那颗带有行星的恒星275E1，距太阳系有多远？', '187J3X1恒星什么时间被摧毁的？', '程心与智子见面后的第二天，来找他的六个公元人的年龄范围？', '情报解读委员会（IDC）的第一次会议是在哪里召开的？', '查尔斯·米什内尔是谁？']

# %%
print(len(ans))
for e in ans:
    for a in e:
        print(a)
    print('================')
print('=====')
# Out:
# 10
# {'content': '整理好的落叶松就要被履带拖拉机拖走了，在树干另一头，叶文洁轻轻抚摸了一下那崭新的锯断面，她常常下意识地这么做，总觉得那是一处巨大的伤口，似乎能感到大树的剧痛。她突然看到，在不远处树桩的锯断面上，也有一只在轻轻抚摸的手，那手传达出的心灵的颤抖，与她产生了共振。那手虽然很白皙，但能够看出是属于男性的。叶文洁抬头，看到抚摸树桩的人是白沐霖，一个戴眼镜的瘦弱青年，他是兵团《大生产报》的记者，前天刚到连队来采访。叶文洁看过他写的文章，文笔很好，其中有一种与这个粗放环境很不协调的纤细和敏感，令她很难忘。', 'start': 7293, 'end': 7462, 'doc': '3body.txt', 'query': '白沐霖在《大生产报》一直工作到哪一年？'}
# {'content': '“马钢，你过来。”白沐霖对不远处一个小伙子喊道，那人壮得像这棵刚被他伐倒的落叶松。他走过来，白记者问道：“你知道这棵树多大年纪了？”\n“数数呗。”马钢指指树桩上的年轮说。\n“我数了，三百三十多岁呢。你锯倒它用了多长时间？”\n“不到十分钟吧，告诉你，我是连里最快的油锯手，我到哪个班，流动红旗就跟我到那儿。”马钢看上去很兴奋，让白记者注意到的人都这样，能在《大生产报》的通讯报道上露一下脸也是很光荣的事。', 'start': 7463, 'end': 7612, 'doc': '3body.txt', 'query': '白沐霖在《大生产报》一直工作到哪一年？'}
# {'content': '“三百多年，十几代人啊，它发芽时还是明朝呢，这漫长的岁月里，它经历过多少风雨，见过多少事。可你几分钟就把它锯倒了，你真没感觉到什么？”\n“你想让我感觉到什么呢？”马钢愣了一下，“不就一棵树嘛，这里最不缺的就是树，比它岁数长的老松多的是。”\n“忙你的去吧。”白沐霖摇摇头，坐在树桩子上轻轻叹息了一声。马钢也摇摇头，记者没有报道他的兴趣，令他很失望。“知识分子毛病就是多。”他说的时候还瞟了一眼不远处的叶文洁，他的话显然也包括了她。', 'start': 7613, 'end': 7758, 'doc': '3body.txt', 'query': '白沐霖在《大生产报》一直工作到哪一年？'}
# ...
